# %% [markdown]
# # Import the dataset and Load the dataset. Load the necessary libraries.

# %% [markdown]
# ## Q1. Show the last 10 records of the dataset. (2 point)

# %%
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 1146           Karachi      2.9  Errand/Supplies
# 1147           Karachi      4.6  Errand/Supplies
# 1148           Karachi      4.6          Meeting
# 1149           Karachi      0.8   Customer Visit
# 1150           Karachi      0.7          Meeting
# 1151  Unknown Location      3.9   Temporary Site
# 1152  Unknown Location     16.2          Meeting
# 1153           Gampaha      6.4   Temporary Site
# 1154         Ilukwatta     48.2   Temporary Site
# 1155               NaN  12204.7              NaN

# %% [markdown]
# ## Q2. Show the first 10 records of the dataset. (2 points)

# %%
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# 5  West Palm Beach     4.3   Meal/Entertain
# 6       Palm Beach     7.1          Meeting
# 7             Cary     0.8          Meeting
# 8      Morrisville     8.3          Meeting
# 9         New York    16.5   Customer Visit

# %% [markdown]
# ## Q3. Show the dimension of the dataset. (2 points)

# %%
# Out:
# 2

# %%
# Out:
# (1156, 7)

# %% [markdown]
# ## Q4. Show the size of the dataset. (2 points)

# %%
# Out:
# 8092

# %% [markdown]
# ## Q5. Print the information about all the variables of the data set. (2 points)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
# START_DATE*    1156 non-null object
# END_DATE*      1155 non-null object
# CATEGORY*      1155 non-null object
# START*         1155 non-null object
# STOP*          1155 non-null object
# MILES*         1156 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Q6. Check for missing values. (2 points)

# %%
# Out:
# True

# %% [markdown]
# ## Q7. How many missing values are present? (2 points)

# %%
# Out:
# 507

# %% [markdown]
# ## Q8. Get the initial data (name it 'df') with dropping the NA values. (2 points)

# %%
# Out:
# 0

# %% [markdown]
# ## Q9. Get the summary of the original data (before dropping the 'na' values). (2 points)

# %%
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %% [markdown]
# ## Q10. Check the information of the new dataframe. (2 points)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
# START_DATE*    653 non-null object
# END_DATE*      653 non-null object
# CATEGORY*      653 non-null object
# START*         653 non-null object
# STOP*          653 non-null object
# MILES*         653 non-null float64
# PURPOSE*       653 non-null object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Q11. Get the unique start destinations. (2 points)
# ### Note: This question is based on the dataframe with no 'na' values in the 'START' variable.

# %%
# Out:
# 0             Fort Pierce
# 1             Fort Pierce
# 2             Fort Pierce
# 3             Fort Pierce
# 4             Fort Pierce
# 5         West Palm Beach
# 6         West Palm Beach
# 7                    Cary
# 8                    Cary
# 9                 Jamaica
# 10               New York
# 11               Elmhurst
# 12                Midtown
# 13            East Harlem
# 14      Flatiron District
# 15                Midtown
# 16           Midtown East
# 17                Midtown
# 18          Hudson Square
# 19        Lower Manhattan
# 20          Hudson Square
# 21         Hell's Kitchen
# 22               New York
# 23               Downtown
# 24                Gulfton
# 25                Houston
# 26             Eagan Park
# 27            Morrisville
# 28                   Cary
# 29                 Durham
#               ...
# 1125              Karachi
# 1126     Unknown Location
# 1127              Karachi
# 1128              Karachi
# 1129     Unknown Location
# 1130              Karachi
# 1131              Karachi
# 1132              Karachi
# 1133              Karachi
# 1134     Unknown Location
# 1135              Karachi
# 1136              Karachi
# 1137              Karachi
# 1138              Karachi
# 1139              Karachi
# 1140              Karachi
# 1141     Unknown Location
# 1142              Karachi
# 1143              Karachi
# 1144     Unknown Location
# 1145              Karachi
# 1146              Karachi
# 1147              Karachi
# 1148              Karachi
# 1149              Karachi
# 1150              Karachi
# 1151              Karachi
# 1152     Unknown Location
# 1153           Katunayake
# 1154              Gampaha
# Name: START*, Length: 1155, dtype: object

# %%
# Out:
# {'Agnew',
#  'Almond',
#  'Apex',
#  'Arabi',
#  'Arlington',
#  'Arlington Park at Amberly',
#  'Asheville',
#  'Austin',
#  'Banner Elk',
#  'Bellevue',
#  'Berkeley',
#  'Boone',
#  'Briar Meadow',
#  'Bryson City',
#  'Burtrose',
#  'CBD',
#  'Capitol One',
#  'Cary',
#  'Central',
#  'Chalmette',
#  'Chapel Hill',
#  'Chessington',
#  'College Avenue',
#  'Colombo',
#  'Columbia Heights',
#  'Congress Ave District',
#  'Connecticut Avenue',
#  'Convention Center District',
#  'Cory',
#  'Couples Glen',
#  'Covington',
#  'Coxville',
#  'Daytona Beach',
#  'Downtown',
#  'Durham',
#  'Eagan Park',
#  'Eagle Rock',
#  'East Austin',
#  'East Elmhurst',
#  'East Harlem',
#  'Eastgate',
#  'Edgehill Farms',
#  'El Cerrito',
#  'Elk Park',
#  'Elmhurst',
#  'Emeryville',
#  'Fairmont',
#  'Farmington Woods',
#  'Fayetteville Street',
#  'Financial District',
#  'Flatiron District',
#  'Florence',
#  'Fort Pierce',
#  'Fuquay-Varina',
#  'Galveston',
#  'Gampaha',
#  'Georgian Acres',
#  'Gulfton',
#  'Hayesville',
#  'Hazelwood',
#  "Hell's Kitchen",
#  'Heritage Pines',
#  'Holly Springs',
#  'Houston',
#  'Hudson Square',
#  'Huntington Woods',
#  'Ingleside',
#  'Islamabad',
#  'Jackson Heights',
#  'Jacksonville',
#  'Jamaica',
#  'Jamestown Court',
#  'K Street',
#  'Kalorama Triangle',
#  'Karachi',
#  'Katunayaka',
#  'Katunayake',
#  'Katy',
#  'Kenner',
#  'Kilarney Woods',
#  'Kissimmee',
#  'Krendle Woods',
#  'Lahore',
#  'Lake Reams',
#  'Lake Wellingborough',
#  'Lakeview',
#  'Latta',
#  'Lexington Park at Amberly',
#  'Long Island City',
#  'Lower Garden District',
#  'Lower Manhattan',
#  'Mandeville',
#  'Marigny',
#  'Mcvan',
#  'Mebane',
#  'Medical Centre',
#  'Menlo Park',
#  'Meredith',
#  'Meredith Townes',
#  'Metairie',
#  'Midtown',
#  'Midtown East',
#  'Morrisville',
#  'Mountain View',
#  'NOMA',
#  'New Orleans',
#  'New York',
#  'Newark',
#  'Newland',
#  'Noorpur Shahan',
#  'North Austin',
#  'North Berkeley Hills',
#  'Northwoods',
#  'Nugegoda',
#  'Oakland',
#  'Old City',
#  'Orlando',
#  'Palo Alto',
#  'Parkway',
#  'Parkwood',
#  'Pontchartrain Beach',
#  'Pontchartrain Shores',
#  'Port Bolivar',
#  'Preston',
#  'R?walpindi',
#  'Raleigh',
#  'Rawalpindi',
#  'Red River District',
#  'Redmond',
#  'Renaissance',
#  'Ridgeland',
#  'Rose Hill',
#  'SOMISSPO',
#  'San Francisco',
#  'San Jose',
#  'Sand Lake Commons',
#  'Santa Clara',
#  'Savon Height',
#  'Seaport',
#  'Seattle',
#  'Sharpstown',
#  'Sky Lake',
#  'Soho',
#  'South',
#  'South Berkeley',
#  'South Congress',
#  'Southside',
#  'St Thomas',
#  'Stonewater',
#  'Storyville',
#  'Sugar Land',
#  'Summerwinds',
#  'Sunnyside',
#  'Sunnyvale',
#  'Tanglewood',
#  'Tenderloin',
#  'The Drag',
#  'Topton',
#  'Townes at Everett Crossing',
#  'Tribeca',
#  'University District',
#  'Unknown Location',
#  'Wake Co.',
#  'Wake Forest',
#  'Washington',
#  'Washington Avenue',
#  'Waverly Place',
#  'Wayne Ridge',
#  'West Berkeley',
#  'West End',
#  'West Palm Beach',
#  'West University',
#  'Weston',
#  'Westpark Place',
#  'Whitebridge',
#  'Winston Salem'}

# %% [markdown]
# ## Q12. What is the total number of unique start destinations? (2 points)
# ### Note: This question is based on the dataframe with no 'na' values in the 'START' variable.

# %%
len(unique)
# Out:
# 176

# %% [markdown]
# ## Q13. Print the total number of unique stop destinations. (2 points)
# ### Note: This question is based on the dataframe with no 'na' values in the 'STOP' variable.

# %%
stop = mydata["STOP*"].dropna()
unique = set(stop)
len(unique)
# Out:
# 187

# %% [markdown]
# ## Q14. Print all the Uber trips that has the starting point of San Francisco. (2 points)
# ### Note: Use the original dataframe without dropping the 'na' values.

# %%
mydata.loc[mydata["START*"]=="San Francisco"]
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## Q15. What is the most popular starting point for the Uber drivers? (2 points)
# ### Note: This question is based on the dataframe with no 'na' values in the 'START' variable.

# %%
start=mydata["START*"].dropna()
df1 = pd.DataFrame(start.value_counts())
df1=df1.reset_index()
df1=df1.rename(columns={'index':'STARTPT', 'START*': 'Count'})
df1.loc[df1['Count']==max(df1['Count'])
# Out:
#                             START*
# Cary                           201
# Unknown Location               148
# Morrisville                     85
# Whitebridge                     68
# Islamabad                       57
# Durham                          37
# Lahore                          36
# Karachi                         31
# Raleigh                         28
# Apex                            17
# Westpark Place                  17
# Berkeley                        16
# Midtown                         14
# R?walpindi                      11
# Kenner                          11
# Kissimmee                       11
# New Orleans                     10
# Emeryville                      10
# Downtown                         9
# Central                          8
# Edgehill Farms                   8
# Banner Elk                       8
# Orlando                          8
# Colombo                          8
# San Francisco                    8
# The Drag                         7
# Hazelwood                        7
# Oakland                          7
# Covington                        6
# Preston                          6
# ...                            ...
# North Berkeley Hills             1
# Summerwinds                      1
# Flatiron District                1
# Ridgeland                        1
# Almond                           1
# Lower Manhattan                  1
# Ingleside                        1
# Sunnyside                        1
# Convention Center District       1
# Mebane                           1
# Elmhurst                         1
# Redmond                          1
# Seaport                          1
# Florence                         1
# Medical Centre                   1
# Katy                             1
# College Avenue                   1
# Lake Wellingborough              1
# Burtrose                         1
# East Harlem                      1
# Bellevue                         1
# Jackson Heights                  1
# Arlington Park at Amberly        1
# Eagle Rock                       1
# Tenderloin                       1
# Coxville                         1
# Sky Lake                         1
# Soho                             1
# Marigny                          1
# Nugegoda                         1
#
# [176 rows x 1 columns]

# %% [markdown]
# ## Q16. What is the most popular dropping point for the Uber drivers? (2 points)
# ### Note: This question is based on the dataframe with no 'na' values in the 'STOP' variable.

# %%
df1=mydata.dropna()
df1 = pd.DataFrame(df1.groupby(['START*','STOP*']).size())
df1
#df1.loc[df1['Count']==max(df1['Count'])]
# Out:
#                                         0
# START*          STOP*
# Apex            Cary                   10
#                 Holly Springs           1
# Arabi           Metairie                1
# Asheville       Topton                  1
# Austin          Katy                    1
# Banner Elk      Banner Elk              1
#                 Boone                   1
# Bellevue        Seattle                 1
# Berkeley        El Cerrito              1
#                 Menlo Park              1
#                 Mountain View           1
#                 Oakland                 2
#                 San Francisco           3
# Boone           Cary                    1
# Briar Meadow    Midtown                 1
# Burtrose        Whitebridge             1
# CBD             Lower Garden District   1
# Capitol One     Mcvan                   1
#                 University District     1
# Cary            Apex                   11
#                 Cary                   44
#                 Chapel Hill             1
#                 Durham                 30
#                 Fuquay-Varina           1
#                 Holly Springs           1
#                 Latta                   1
#                 Morrisville            52
#                 Raleigh                17
#                 Unknown Location        1
#                 Wake Co.                1
# ...                                    ..
# Waverly Place   Macgregor Downs         1
#                 Whitebridge             2
# Wayne Ridge     Whitebridge             3
# West Berkeley   South                   1
#                 Southside               1
# West Palm Beach Palm Beach              1
#                 West Palm Beach         1
# West University Congress Ave District   1
# Weston          Weston                  1
# Westpark Place  Whitebridge             5
# Whitebridge     Burtrose                1
#                 Chessington             1
#                 Edgehill Farms          3
#                 Hazelwood               2
#                 Heritage Pines          1
#                 Kildaire Farms          1
#                 Macgregor Downs         1
#                 Northwoods              1
#                 Parkway                 2
#                 Preston                 1
#                 Savon Height            3
#                 Stonewater              1
#                 Summerwinds             1
#                 Tanglewood              3
#                 Waverly Place           4
#                 Wayne Ridge             4
#                 Westpark Place          3
#                 Whitebridge             2
#                 Williamsburg Manor      1
# Winston Salem   Asheville               1
#
# [239 rows x 1 columns]

# %% [markdown]
# ## Q17. List the most frequent route taken by Uber drivers. (3 points)
# ### Note: This question is based on the dataframe with no 'na' values.

# %%
df2=mydata.dropna()
df2 = pd.DataFrame(df2.groupby(['START*','STOP*']).size())

df2=df2.rename(columns={0:'Count'})
df2.loc[df2['Count']==max(df2['Count'])]
# Out:
#                     Count
# START* STOP*
# Cary   Morrisville     52

# %% [markdown]
# ## Q18. Print all types of purposes for the trip in an array. (3 points)
#    ### Note: This question is based on the dataframe with no 'na' values in the 'PURPOSE' variable.

# %%
x = np.array(mydata['PURPOSE*'].dropna().unique())
mydata['MILES*'].groupby(mydata['PURPOSE*']).sum()

#purpose = mydata['PURPOSE*'].dropna()
#unique = set(purpose)
#unique
# Out:
# PURPOSE*
# Airport/Travel       16.5
# Between Offices     197.0
# Charity ($)          15.1
# Commute             180.2
# Customer Visit     2089.5
# Errand/Supplies     508.0
# Meal/Entertain      911.7
# Meeting            2851.3
# Moving               18.2
# Temporary Site      523.7
# Name: MILES*, dtype: float64

# %% [markdown]
# ## Q19. Plot a bar graph of Purposes vs Distance. (3 points)
# ### Note: This question is based on the original dataframe.

# %%
 df1=pd.DataFrame(mydata['MILES*'].groupby(mydata['PURPOSE*']).sum())
df1.plot(kind = "bar")
plt.show()

# %%
df1=df1.reset_index()
sns.barplot(x=df1['MILES*'], y=df1['PURPOSE*'])

# %% [markdown]
# ## Q20. Print a dataframe of Purposes and the distance travelled for that particular Purpose. (3 points)
# ### Note: This question is based on the orignial dataframe.

# %%
df
# Out:
#                  MILES*
# PURPOSE*
# Airport/Travel     16.5
# Between Offices   197.0
# Charity ($)        15.1
# Commute           180.2
# Customer Visit   2089.5
# Errand/Supplies   508.0
# Meal/Entertain    911.7
# Meeting          2851.3
# Moving             18.2
# Temporary Site    523.7

# %% [markdown]
# ## Q21. Plot number of trips vs Category of trips. (3 points)
# ### Note: This question is based on the original dataframe.

# %%
df=pd.DataFrame(mydata['CATEGORY*'].value_counts())
df.plot(kind= "bar")
plt.show()

# %%
df=pd.DataFrame(df.reset_index())
df=df.rename(columns={'index':'Category', 'CATEGORY*':'Count'})
sns.barplot(x=df['Category'], y=df['Count'])

# %% [markdown]
# ## Q22. What is proportion of trips that is Business and what is the proportion of trips that is Personal? (3 points)
# ### Note: The proportion calculation  is with respect to the 'miles' variable.
# ### Note: This question is based on the original dataframe.

# %%
df=mydata.groupby(['CATEGORY*']).sum()
b= df.iloc[0,0]/(df.iloc[0,0]+df.iloc[1,0])
p= df.iloc[1,0]/(df.iloc[0,0]+df.iloc[1,0])
print("Business - ", b)
print("Personal - ", p)
# Out:
# Business -  0.9411947856153777
# Personal -  0.05880521438462235
